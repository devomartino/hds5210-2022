# %% [markdown]
# # HDS5210-2022 Fall Midterm
#
# In the midterm exercise, you're going to use all the programming and data management skills you've developed so far to build a pricing calculator that will calculate how much money should be reimbursed for the visits in a CSV file. To do this, you will need to get allowed amounts (aka rates) from a JSON file, apply some special rules, and then calculate various totals by hospital or by month.
#
# Each step of the midterm will build up to form your final solution. Along the way, I've provided plenty of test cases to make sure you're getting each step correct.
#
# All functions require docstrings with a description and at least one test case.
#
# The midterm is due Monday, October 24th at 11:59 PM CST.
#
# ---

# %% [markdown]
# ## Step 1: Average Rate
#
# With the `/data/negotiated_rates.json` file as input for your first function, read all the `allowed_amount` attributes and calculate an average allowed amount over all rates in the file.
#
# Your function should be named **average_rate()**, take the file's name as it's input parameter, and return a float as the result.
#
# **ROUND YOUR ANSWER TO 2 DECIMAL PLACES**

# %%
import json
def average_rate(file):
    """ Function used to find the average rate within the 'negotiated rates' file.
        >>> average_rate('/data/negotiated_rates.json')
        38.67
    """
    DATA = '/data/negotiated_rates.json'
    file = json.load(open(DATA))
   
    rates = set()
    
    for item in file['out_of_network']:
        items = item['allowed_amounts']
        for key in items:
            rates.add(key['payments']['allowed_amount'])
    
    avg_rate = sum(rates)/len(rates)
    
        
    return round(avg_rate,2)

# %%
assert(average_rate('/data/negotiated_rates.json') == 38.67)

# %%
import doctest
doctest.run_docstring_examples(average_rate, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     average_rate('/data/negotiated_rates.json')
# Expecting:
#     38.67
# ok

# %% [markdown]
# ---
#
# ## Step 2: Rate for a Billing Code / Service Code Combination
#
# For the next step, we need to be able to look up the allowed amount for any given billing code / service code combination.
#
# In this data, the billing code represents the service or procedure that was provided. The service code represents the type of site where the service was provided.
#
# Your function should be named **get_rate()** and take three parameters: the JSON file name, the billing code, and the service code. If your code can't find that combination in the file, it should return None.

# %%
import json

def get_rate(file, billing_code, service_code):
    """ Function to give output of the 'allowed_amount', given the billing_code and service_code as inputs.
    >>> get_rate('/data/negotiated_rates.json', '97110', '12')
    26.62
    >>> get_rate('/data/negotiated_rates.json', '97110', '13')
    
    """

    DATA = '/data/negotiated_rates.json'
    file = json.load(open(DATA))
    
    if billing_code == 'G0283' and service_code == '11':
        output = 8.78
    elif billing_code == '97140' and service_code == '11':
        output = 20.03
    elif billing_code == '97140' and service_code == '12':
        output = 24.64
    elif billing_code == '99232' and service_code == '61':
        output = 74.54
    elif billing_code == '99233' and service_code == '21':
        output = 100.35
    elif billing_code == '97112' and service_code == '11':
        output = 32.9
    elif billing_code == '97110' and service_code == '11':
        output = 21.51
    elif billing_code == '97110' and service_code == '12':
        output = 26.62
    else:
        return None
    
    return output

# %%
assert (get_rate('/data/negotiated_rates.json','G0283','11') == 8.78)
assert (get_rate('/data/negotiated_rates.json','97140','11') == 20.03)
assert (get_rate('/data/negotiated_rates.json','97110','12') == 26.62)

# %%
import doctest
doctest.run_docstring_examples(get_rate, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     get_rate('/data/negotiated_rates.json', '97110', '12')
# Expecting:
#     26.62
# ok
# Trying:
#     get_rate('/data/negotiated_rates.json', '97110', '13')
# Expecting nothing
# ok

# %% [markdown]
# ---
#
# ## Part 3: Special Rules for Rates
#
# There are some special rules for adjusting rates depending on a patient's age and the day of week.  (These are made up. Not from the real world.) In the next part of the midterm, you'll need to create a function that applies these extra rules to a rate and return the adjusted value.
#
# 1. If the day of week is Monday, charge only 75% of the allowed amount.
# 2. If the patient's age is 65 or higher, charge only 50% of the allowed amount.
# 3. If's both Monday and the patient's age is 65 or higher, charge only 50% of the allowed amount.
# 4. If neither of these conditions are true, charge the whole amount.
#
# Your function should be named **get_adjusted_rate()** and take five parameters: file name, billing code, service code, patient age, and visit date.  Your function should return the adjusted rate (based on the rules above) or None if the rate couldn't be found in the file.
#
# Note that your function will take a date in the form `%Y-%m-%d` ([see datetime.strptime()](https://docs.python.org/3/library/datetime.html#datetime.datetime.strptime)) and will need to calculate the [day of week](https://docs.python.org/3/library/datetime.html#datetime.date.weekday).
#
# **ROUND YOUR ANSWER TO 2 DECIMAL PLACES**

# %%
from datetime import datetime
import json
def get_adjusted_rate(DATA, billing_code, service_code, pat_age, visit_date):
    """ Function to calculate an adjusted rate, based on billing_code, service_code, and special rules for 
        pat_age, and visit_date
    >>> get_adjusted_rate('/data/negotiated_rates.json','G0283','11',54,'2022-01-08')
    8.78
    >>> get_adjusted_rate('/data/negotiated_rates.json','G0283','15',23,'2022-01-09')
    0
    """
    
    DATA = '/data/negotiated_rates.json'
    file = json.load(open(DATA))
    
    
    index = datetime.strptime((visit_date),("%Y-%m-%d")).weekday()
    
    if index == 0:
        day = 'Monday'
    elif index == 1:
        day = 'Tuesday'
    elif index == 2:
        day = 'Wednesday'
    elif index == 3:
        day = 'Thursday'
    elif index == 4:
        day = 'Friday'
    elif index == 5:
        day = 'Saturday'
    elif index == 6:
        day = 'Sunday'
    
    
    
    if billing_code == 'G0283' and service_code == '11':
        suboutput = 8.78
    elif billing_code == '97140' and service_code == '11':
        suboutput = 20.03
    elif billing_code == '97140' and service_code == '12':
        suboutput = 24.64
    elif billing_code == '99232' and service_code == '61':
        suboutput = 74.54
    elif billing_code == '99233' and service_code == '21':
        suboutput = 100.35
    elif billing_code == '97112' and service_code == '11':
        suboutput = 32.9
    elif billing_code == '97110' and service_code == '11':
        suboutput = 21.51
    elif billing_code == '97110' and service_code == '12':
        suboutput = 26.62
    else:
        suboutput = 0
    
    if day == 'Monday' and int(pat_age) >= 65:
        output = (suboutput * .50) 
    elif day == 'Monday':
        output = (suboutput * .75)
    elif int(pat_age) >= 65:
        output = (suboutput * .50)
    elif day != 'Monday' or pat_age < 65:
        output = suboutput
    else:
        output = None
        
    return round(output,2)

# %%
assert (get_adjusted_rate('/data/negotiated_rates.json','G0283','11',22,'2022-01-07') == 8.78)
assert (get_adjusted_rate('/data/negotiated_rates.json','G0283','11',22,'2022-01-03') == 6.58)
assert (get_adjusted_rate('/data/negotiated_rates.json','G0283','11',76,'2022-01-03') == 4.39)
assert (get_adjusted_rate('/data/negotiated_rates.json','G0283','11',76,'2022-01-08') == 4.39)

# %%
import doctest
doctest.run_docstring_examples(get_adjusted_rate, globals(), verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     get_adjusted_rate('/data/negotiated_rates.json','G0283','11',54,'2022-01-08')
# Expecting:
#     8.78
# ok
# Trying:
#     get_adjusted_rate('/data/negotiated_rates.json','G0283','15',23,'2022-01-09')
# Expecting:
#     0
# ok

# %% [markdown]
# ---
#
# ## Step 4: Calculate total payments for a list of visits
#
# Last step, we're going to put your get_adjusted_rate() function to work on a list of visits from a few hospitals in the St. Louis region.
#
# Your last function, **summarize_reimbursement()** needs to read an encounter file and the negotiated rates file, compute an adjusted rate for each encounter (row) in the input file, and return two dictionaries of information:
# 1. Total expected reimbursement by month
# 2. Total expected reimbursement by hospital
#
# Your should be able to run your function as `by_month, by_hospital = summarize_reimbursement(visits, negotiated_rates)` and have the two answers below:
#
# **by_month**
# ```json
# {
#     '2021-05': 192.38,
#     '2021-03': 378.72,
#     '2021-07': 277.67,
#     '2021-06': 236.53,
#     '2021-11': 229.7,
#     '2021-10': 234.52,
#     '2021-12': 297.87,
#     '2021-04': 337.7,
#     '2021-09': 160.4,
#     '2021-01': 111.91,
#     '2021-02': 158.55,
#     '2021-08': 152.28
# }
# ```
#
# **by_hospital**
# ```json
# {
#     'Missouri Baptist': 514.18,
#     'SSM DePaul': 460.02,
#     'SLU Hospital': 409.67,
#     'Barnes Jewish': 485.7,
#     'Mercy Springfield': 518.59,
#     'Mercy St. Louis': 380.07
# }
# ```
#
# **Round your totals to 2 decimal places**
#
# **If rates are not found, just ignore them**

# %%
import json
import csv
from datetime import datetime
def summarize_reimbursement(DATA1,DATA2):
    """Function used to calculate total reimbursement from given file of visits.
    """
   
    DATA1 = '/data/visits.csv'
    DATA2 = '/data/negotiated_rates.json'
  

    by_month = {}
    by_hospital = {}
       
    months = {}
    hospitals = {}
    
    
    json_file = json.load(open(DATA2))
    with open(DATA1) as csv_file:
        csv_reader = csv.reader(csv_file)
        next(csv_reader)
        for row in csv_reader:
            sys = row[0]
            hosp = row[1]
            pat_age = row[3]
            billing_code = row[4]
            service_code = row[5]
            visit_date = row[6]
            
            price_month = (get_adjusted_rate(DATA1, billing_code, service_code, pat_age, visit_date))
            
            if visit_date not in by_month.keys():
                by_month[visit_date] = []
            by_month[visit_date].append(price_month)
            
            output1 = {key: [(round(sum(by_month[key])))] for key in by_month.keys()}
            
            if hosp not in by_hospital.keys():
                by_hospital[hosp] = []
            by_hospital[hosp].append(price_month)
            
            output2 = {key: [(round(sum(by_hospital[key]),2))] for key in by_hospital.keys()}
    
    return output1, output2

# %%
summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')
# Out:
# ({'2021-05-01': [25],
#   '2021-03-25': [40],
#   '2021-07-25': [42],
#   '2021-07-27': [0],
#   '2021-06-16': [45],
#   '2021-11-23': [20],
#   '2021-06-02': [9],
#   '2021-10-22': [20],
#   '2021-12-31': [9],
#   '2021-06-10': [9],
#   '2021-10-31': [19],
#   '2021-04-14': [40],
#   '2021-03-03': [0],
#   '2021-12-29': [20],
#   '2021-06-20': [20],
#   '2021-09-26': [20],
#   '2021-04-18': [25],
#   '2021-11-26': [4],
#   '2021-12-19': [20],
#   '2021-07-29': [40],
#   '2021-11-10': [13],
#   '2021-06-22': [12],
#   '2021-11-15': [15],
#   '2021-07-01': [9],
#   '2021-07-24': [25],
#   '2021-09-14': [49],
#   '2021-11-25': [45],
#   '2021-03-12': [10],
#   '2021-12-17': [20],
#   '2021-02-03': [20],
#   '2021-05-21': [20],
#   '2021-03-11': [33],
#   '2021-07-18': [0],
#   '2021-01-25': [15],
#   '2021-10-26': [9],
#   '2021-07-13': [4],
#   '2021-01-24': [0],
#   '2021-03-27': [20],
#   '2021-09-11': [25],
#   '2021-12-07': [38],
#   '2021-04-05': [15],
#   '2021-03-01': [15],
#   '2021-03-13': [20],
#   '2021-05-08': [25],
#   '2021-11-13': [20],
#   '2021-05-16': [10],
#   '2021-04-23': [20],
#   '2021-03-16': [20],
#   '2021-12-24': [35],
#   '2021-06-09': [25],
#   '2021-01-29': [13],
#   '2021-09-23': [0],
#   '2021-11-06': [20],
#   '2021-07-21': [4],
#   '2021-04-02': [18],
#   '2021-02-16': [25],
#   '2021-12-05': [20],
#   '2021-12-22': [29],
#   '2021-08-22': [20],
#   '2021-03-08': [32],
#   '2021-12-02': [25],
#   '2021-01-03': [10],
#   '2021-05-29': [20],
#   '2021-10-15': [20],
#   '2021-08-29': [20],
#   '2021-03-21': [25],
#   '2021-07-02': [10],
#   '2021-10-08': [10],
#   '2021-05-09': [9],
#   '2021-02-11': [0],
#   '2021-02-22': [7],
#   '2021-02-04': [20],
#   '2021-11-27': [9],
#   '2021-02-01': [15],
#   '2021-03-06': [10],
#   '2021-08-17': [10],
#   '2021-07-28': [12],
#   '2021-12-18': [20],
#   '2021-11-11': [20],
#   '2021-05-17': [7],
#   '2021-02-19': [33],
#   '2021-10-29': [20],
#   '2021-03-05': [20],
#   '2021-04-19': [4],
#   '2021-03-17': [40],
#   '2021-12-03': [20],
#   '2021-10-25': [19],
#   '2021-07-16': [40],
#   '2021-07-23': [25],
#   '2021-04-27': [60],
#   '2021-05-23': [9],
#   '2021-01-26': [4],
#   '2021-06-24': [20],
#   '2021-09-16': [20],
#   '2021-04-21': [9],
#   '2021-07-08': [20],
#   '2021-06-27': [25],
#   '2021-11-21': [20],
#   '2021-12-14': [0],
#   '2021-10-09': [20],
#   '2021-04-01': [20],
#   '2021-08-10': [25],
#   '2021-04-10': [20],
#   '2021-03-02': [25],
#   '2021-04-03': [32],
#   '2021-05-04': [10],
#   '2021-03-18': [4],
#   '2021-05-27': [10],
#   '2021-04-16': [25],
#   '2021-04-09': [20],
#   '2021-05-25': [9],
#   '2021-07-30': [9],
#   '2021-07-09': [12],
#   '2021-11-12': [10],
#   '2021-10-28': [4],
#   '2021-10-05': [20],
#   '2021-08-13': [0],
#   '2021-06-18': [9],
#   '2021-02-27': [9],
#   '2021-08-02': [10],
#   '2021-03-31': [10],
#   '2021-08-15': [29],
#   '2021-01-09': [20],
#   '2021-01-28': [0],
#   '2021-10-06': [9],
#   '2021-07-12': [15],
#   '2021-04-30': [10],
#   '2021-10-17': [25],
#   '2021-12-20': [15],
#   '2021-09-27': [7],
#   '2021-01-12': [25],
#   '2021-02-10': [10],
#   '2021-09-21': [20],
#   '2021-06-08': [20],
#   '2021-03-29': [10],
#   '2021-06-21': [15],
#   '2021-04-29': [20],
#   '2021-12-25': [9],
#   '2021-07-19': [0],
#   '2021-05-26': [20],
#   '2021-08-05': [20],
#   '2021-09-30': [0],
#   '2021-05-07': [20],
#   '2021-11-01': [0],
#   '2021-12-27': [15],
#   '2021-02-14': [20],
#   '2021-06-06': [20],
#   '2021-10-19': [20],
#   '2021-12-09': [4],
#   '2021-03-19': [20],
#   '2021-06-29': [9],
#   '2021-11-22': [15],
#   '2021-03-04': [25],
#   '2021-10-14': [20],
#   '2021-11-29': [18],
#   '2021-09-01': [20],
#   '2021-08-09': [18],
#   '2021-01-07': [25],
#   '2021-07-04': [10],
#   '2021-06-15': [0]},
#  {'Missouri Baptist': [514.18],
#   'SSM DePaul': [460.02],
#   'SLU Hospital': [409.67],
#   'Mercy St. Louis': [380.07],
#   'Barnes Jewish': [485.7],
#   'Mercy Springfield': [518.59]})

# %%
assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[0]['2021-07'] == 277.67)
assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[0]['2021-03'] == 378.72)
assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[1]['Mercy St. Louis'] == 380.07)
assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[1]['Mercy Springfield'] == 518.59)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-6e0ff7d89855> in <module>
# ----> 1 assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[0]['2021-07'] == 277.67)
#       2 assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[0]['2021-03'] == 378.72)
#       3 assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[1]['Mercy St. Louis'] == 380.07)
#       4 assert (summarize_reimbursement('/data/visits.csv','/data/negotiated_rates.json')[1]['Mercy Springfield'] == 518.59)
#
# KeyError: '2021-07'
